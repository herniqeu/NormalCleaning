# %%
from google.colab import drive
import pandas as pd 
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_classification
import numpy as np 
import plotly.express as px

drive.mount('/content/drive')

np.random.seed(73)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Mean

# %%
def Mean(numberOfNanX): 
  df_train = pd.read_csv('/content/drive/MyDrive/house-prices-advanced-regression-techniques/train.csv')
  df_test = pd.read_csv('/content/drive/MyDrive/house-prices-advanced-regression-techniques/test.csv')

  df_train = df_train[['LotArea','LotFrontage','SalePrice']]
  df_test = df_test[['LotArea','LotFrontage']]

  df_train.loc[:numberOfNanX, 'LotFrontage'] = np.nan

  LotFrontageMean = df_train['LotFrontage'].mean(skipna=True)
  df_train['LotFrontage'] = df_train['LotFrontage'].fillna(LotFrontageMean)

  X_train = df_train.drop(columns=['SalePrice'])
  y_train = df_train['SalePrice']

  X_test = df_test

  rfMean = RandomForestRegressor(max_depth=9)
  rfMean.fit(X_train,y_train)

  return rfMean.score(X_train,y_train)

# %% [markdown]
# # Media

# %%
def Median(numberOfNanX): 
  df_train = pd.read_csv('/content/drive/MyDrive/house-prices-advanced-regression-techniques/train.csv')
  df_test = pd.read_csv('/content/drive/MyDrive/house-prices-advanced-regression-techniques/test.csv')

  df_train = df_train[['LotArea','LotFrontage','SalePrice']]
  df_test = df_test[['LotArea','LotFrontage']]

  df_train.loc[:numberOfNanX, 'LotFrontage'] = np.nan

  LotFrontageMedian = df_train['LotFrontage'].median()
  df_train['LotFrontage'] = df_train['LotFrontage'].fillna(LotFrontageMedian)

  X_train = df_train.drop(columns=['SalePrice'])
  y_train = df_train['SalePrice']

  X_test = df_test

  rfMedian = RandomForestRegressor(max_depth=9)
  rfMedian.fit(X_train,y_train)

  return rfMedian.score(X_train,y_train)

# %% [markdown]
# # Mode

# %%
def Mode(numberOfNanX): 
  df_train = pd.read_csv('/content/drive/MyDrive/house-prices-advanced-regression-techniques/train.csv')
  df_test = pd.read_csv('/content/drive/MyDrive/house-prices-advanced-regression-techniques/test.csv')

  df_train = df_train[['LotArea','LotFrontage','SalePrice']]
  df_test = df_test[['LotArea','LotFrontage']]

  df_train.loc[:numberOfNanX, 'LotFrontage'] = np.nan

  LotFrontageMode = df_train['LotFrontage'].mode()[0]
  df_train['LotFrontage'] = df_train['LotFrontage'].fillna(LotFrontageMode)

  X_train = df_train.drop(columns=['SalePrice'])
  y_train = df_train['SalePrice']

  X_test = df_test

  rfMode = RandomForestRegressor(max_depth=9)
  rfMode.fit(X_train,y_train)

  return rfMode.score(X_train,y_train)

# %% [markdown]
# # Normal Distribution

# %%
def NormalDistribuition(numberOfNanX): 
  df_train = pd.read_csv('/content/drive/MyDrive/house-prices-advanced-regression-techniques/train.csv')
  df_test = pd.read_csv('/content/drive/MyDrive/house-prices-advanced-regression-techniques/test.csv')

  df_train = df_train[['LotArea','LotFrontage','SalePrice']]
  df_test = df_test[['LotArea','LotFrontage']]

  df_train.loc[:numberOfNanX, 'LotFrontage'] = np.nan

  LotFrontageMean = df_train['LotFrontage'].mean(skipna=True)
  LotFrontageStd = df_train['LotFrontage'].std(skipna=True)

  num_nulls = df_train['LotFrontage'].isnull().sum()
  num_nulls_test = df_test['LotFrontage'].isnull().sum()

  lista_numeros_normal = np.random.normal(LotFrontageMean, LotFrontageStd, num_nulls)

  df_train['LotFrontage'].fillna(pd.Series(lista_numeros_normal, index=df_train.index[df_train['LotFrontage'].isnull()]), inplace=True)

  X_train = df_train.drop(columns=['SalePrice'])
  y_train = df_train['SalePrice']

  X_test = df_test

  rfNormalDistribuition = RandomForestRegressor(max_depth=9)
  rfNormalDistribuition.fit(X_train,y_train)

  return rfNormalDistribuition.score(X_train,y_train)

# %%
TestList = []
for i in range(0, 1201, 50):
  TestList.append(i)

# %%
ResultsList = [[],[],[],[]]
for i in TestList:
  ResultsList[0].append(Mean(i))
  ResultsList[1].append(Median(i))
  ResultsList[2].append(Mode(i))
  ResultsList[3].append(NormalDistribuition(i))

# %%
data = {'Mean': ResultsList[0],
        'Median': ResultsList[1],
        'Mode': ResultsList[2],
        'Normal Distribution': ResultsList[3]
        }

df_Results = pd.DataFrame(data)
df_Results.index = TestList

# %%
df_Results
# Out:
#           Mean    Median      Mode  Normal Distribution
# 0     0.697451  0.696400  0.682566             0.700993
# 50    0.689535  0.696003  0.675723             0.696153
# 100   0.684292  0.686778  0.676282             0.691777
# 150   0.682216  0.687971  0.667831             0.695803
# 200   0.670349  0.664558  0.664893             0.695569
# 250   0.663354  0.660082  0.652259             0.678295
# 300   0.652355  0.653242  0.643753             0.687811
# 350   0.642092  0.643652  0.632647             0.684513
# 400   0.630894  0.628740  0.624006             0.663990
# 450   0.621211  0.622583  0.619410             0.653277
# 500   0.619326  0.615340  0.612513             0.654546
# 550   0.614261  0.613661  0.611945             0.657225
# 600   0.610749  0.610542  0.605946             0.648019
# 650   0.608934  0.602201  0.608117             0.649750
# 700   0.583487  0.603421  0.592864             0.649550
# 750   0.586318  0.589876  0.597323             0.640473
# 800   0.581137  0.578928  0.587896             0.628981
# 850   0.577217  0.577228  0.578599             0.641563
# 900   0.568883  0.566029  0.571411             0.650605
# 950   0.562210  0.573972  0.563909             0.625280
# 1000  0.557372  0.557604  0.570671             0.632985
# 1050  0.554162  0.548126  0.560409             0.624780
# 1100  0.547229  0.549364  0.558563             0.623678
# 1150  0.549173  0.549348  0.552161             0.623006
# 1200  0.567662  0.560354  0.567236             0.606442

# %%
fig = px.line(df_Results.reset_index(), x='index', y=df_Results.columns)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="37f030ca-c111-48ff-95f2-3988f9fd715e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37f030ca-c111-48ff-95f2-3988f9fd715e")) {                    Plotly.newPlot(                        "37f030ca-c111-48ff-95f2-3988f9fd715e",                        [{"hovertemplate":"variable=Mean<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Mean","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mean","orientation":"v","showlegend":true,"x":[0,50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950,1000,1050,1100,1150,1200],"xaxis":"x","y":[0.6974513302863998,0.6895353013383418,0.6842918037722899,0.6822160275964442,0.6703493730896303,0.6633536655006649,0.6523547790087815,0.6420922838663372,0.6308937972981652,0.6212111643405207,0.6193263611704464,0.6142606988747346,0.6107486634126094,0.6089338468271142,0.5834870603363826,0.5863176317036372,0.5811372393907286,0.5772173504788677,0.5688826578251589,0.5622096889841897,0.5573719293376151,0.5541617416365067,0.547228701057267,0.5491726514941528,0.5676620684317334],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=Median<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Median","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Median","orientation":"v","showlegend":true,"x":[0,50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950,1000,1050,1100,1150,1200],"xaxis":"x","y":[0.6964002941852117,0.6960025710270974,0.6867782415586275,0.6879714084850499,0.6645579807343183,0.6600819339177653,0.6532417483917319,0.6436517874182562,0.6287398866103646,0.6225827440437242,0.6153395914115023,0.6136607458606065,0.6105418843604471,0.6022013674262299,0.6034213523307034,0.589875752054033,0.5789275049532472,0.5772283898627651,0.5660289084699769,0.5739719441889344,0.5576044842889727,0.5481262602200239,0.549364247474766,0.5493479556310463,0.5603541977468476],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=Mode<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Mode","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mode","orientation":"v","showlegend":true,"x":[0,50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950,1000,1050,1100,1150,1200],"xaxis":"x","y":[0.682565597959875,0.6757227720133231,0.6762823228880768,0.6678307684749645,0.6648931900814938,0.6522593468199136,0.6437530991173633,0.6326467830130834,0.6240063629135043,0.619410197680946,0.6125129603601137,0.6119448705467341,0.6059460815914842,0.608116715752371,0.5928641547553126,0.5973234243602932,0.58789622809362,0.5785991748973418,0.5714108501941071,0.5639090620599372,0.5706708443741794,0.5604085887079183,0.5585627058649443,0.552161350775876,0.5672358078012882],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=Normal Distribution<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Normal Distribution","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Normal Distribution","orientation":"v","showlegend":true,"x":[0,50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950,1000,1050,1100,1150,1200],"xaxis":"x","y":[0.7009933194323494,0.6961526050919516,0.6917769301178186,0.6958031232065447,0.6955690638531291,0.6782954007180129,0.687810733733796,0.6845130904311327,0.6639896640909513,0.6532768033959353,0.654546039774095,0.6572245648326435,0.6480191136476854,0.6497504982529512,0.6495496405094554,0.6404726340310938,0.6289807072576221,0.6415625569582769,0.6506054406512181,0.6252796245278105,0.6329849564385444,0.6247798194721497,0.6236779982735781,0.623005697891126,0.606441 ...
